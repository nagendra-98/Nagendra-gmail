# %% [markdown]
# <a href="https://colab.research.google.com/github/nagendra-98/Nagendra-gmail/blob/main/Assess.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
 pd.read_excel('take_home(1).xlsx')
# Out:
#        object_id       creation_time               name  \
# 0              1 2014-04-22 03:53:00     Clausen August
# 1              2 2013-11-15 03:45:00      Poole Matthew
# 2              3 2013-03-19 23:14:00  Bottrill Mitchell
# 3              4 2013-05-21 08:09:00    Clausen Nicklas
# 4              5 2013-01-17 10:14:00          Raw Grace
# ...          ...                 ...                ...
# 11995      11996 2013-09-06 06:14:00       Meier Sophia
# 11996      11997 2013-01-10 18:28:00      Fisher Amelie
# 11997      11998 2014-04-27 12:45:00        Haynes Jake
# 11998      11999 2012-05-31 11:55:00       Faber Annett
# 11999      12000 2014-01-26 08:57:00         Lima Thaís
#
#                             email     creation_source  \
# 0        AugustCClausen@yahoo.com        GUEST_INVITE
# 1          MatthewPoole@gustr.com          ORG_INVITE
# 2      MitchellBottrill@gustr.com          ORG_INVITE
# 3       NicklasSClausen@yahoo.com        GUEST_INVITE
# ...

# %%
df1 = pd.read_excel('take_home(1).xlsx')

# %%
pd.read_excel('take_home(2).xlsx')
# Out:
#                 time_stamp  user_id  visited
# 0      2014-04-22 03:53:00        1        1
# 1      2013-11-15 03:45:00        2        1
# 2      2013-11-29 03:45:00        2        1
# 3      2013-12-09 03:45:00        2        1
# 4      2013-12-25 03:45:00        2        1
# ...                    ...      ...      ...
# 207912 2013-09-06 06:14:00    11996        1
# 207913 2013-01-15 18:28:00    11997        1
# 207914 2014-04-27 12:45:00    11998        1
# 207915 2012-06-02 11:55:00    11999        1
# 207916 2014-01-26 08:57:00    12000        1
#
# [207917 rows x 3 columns]

# %%
df2 = pd.read_excel('take_home(2).xlsx')

# %%
pd.concat([df1, df2], axis = 0)
# Out:
#         object_id       creation_time               name  \
# 0             1.0 2014-04-22 03:53:00     Clausen August
# 1             2.0 2013-11-15 03:45:00      Poole Matthew
# 2             3.0 2013-03-19 23:14:00  Bottrill Mitchell
# 3             4.0 2013-05-21 08:09:00    Clausen Nicklas
# 4             5.0 2013-01-17 10:14:00          Raw Grace
# ...           ...                 ...                ...
# 207912        NaN                 NaT                NaN
# 207913        NaN                 NaT                NaN
# 207914        NaN                 NaT                NaN
# 207915        NaN                 NaT                NaN
# 207916        NaN                 NaT                NaN
#
#                              email creation_source  \
# 0         AugustCClausen@yahoo.com    GUEST_INVITE
# 1           MatthewPoole@gustr.com      ORG_INVITE
# 2       MitchellBottrill@gustr.com      ORG_INVITE
# 3        NicklasSClausen@yahoo.com    GUEST_INVITE
# ...

# %%
df1.loc[:,'last_session_creation_time':'invited_by_user_id']
# Out:
#        last_session_creation_time  opted_in_to_mailing_list  \
# 0                    1.398139e+09                         1
# 1                    1.396238e+09                         0
# 2                    1.363735e+09                         0
# 3                    1.369210e+09                         0
# 4                    1.358850e+09                         0
# ...                           ...                       ...
# 11995                1.378448e+09                         0
# 11996                1.358275e+09                         0
# 11997                1.398603e+09                         1
# 11998                1.338638e+09                         0
# 11999                1.390727e+09                         0
#
#        enabled_for_marketing_drip  org_id  invited_by_user_id
# 0                               0      11             10803.0
# 1                               0       1               316.0
# ...

# %%
df1.drop_duplicates(inplace = True)

# %%
df2.drop_duplicates(inplace = True)

# %%
# Out:
#   File "<ipython-input-106-d82cbfd9ba53>", line 1
#     df.head()_reset_index()
#              ^
# SyntaxError: invalid syntax

# %%
df = pd.concat([df1, df2], axis = 0)

# %%
df["org_id"].unique()
# Out:
# array([ 11.,   1.,  94., 193., 197.,  37.,  74., 302., 318.,  69., 130.,
#        254.,   0., 175., 211.,   2.,  58.,  54.,   7.,   6., 123.,  81.,
#         56., 134.,  92., 251., 283.,  98., 401.,  33.,  59., 109., 276.,
#        208., 332.,  64., 235.,  63.,  14.,   4., 127.,  32., 224., 304.,
#         61.,  51., 229.,  88., 325., 150., 347., 203.,  21., 409., 215.,
#        141.,   5., 107., 184., 310., 367., 389.,  89., 242.,  68.,  16.,
#         49., 185.,  91., 172.,   8.,  43., 249.,  26., 139.,  70.,  10.,
#        252.,  53., 119.,   3., 196., 335., 375., 303., 307.,  25., 370.,
#         83.,  27., 306., 118., 295.,  19., 301., 100., 112., 263.,  39.,
#         12.,  86., 402.,  42., 103., 373., 268.,  30., 406.,  48., 313.,
#          9., 138., 261.,  35., 264.,  95.,  55.,  60., 234.,  28., 410.,
#        170., 374.,  15.,  17., 364.,  62., 244., 342., 225., 121., 255.,
#        411., 217., 165., 415., 104., 329., 278., 116., 151., 290., 200.,
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of         object_id       creation_time               name  \
# 0             1.0 2014-04-22 03:53:00     Clausen August
# 1             2.0 2013-11-15 03:45:00      Poole Matthew
# 2             3.0 2013-03-19 23:14:00  Bottrill Mitchell
# 3             4.0 2013-05-21 08:09:00    Clausen Nicklas
# 4             5.0 2013-01-17 10:14:00          Raw Grace
# ...           ...                 ...                ...
# 207912        NaN                 NaT                NaN
# 207913        NaN                 NaT                NaN
# 207914        NaN                 NaT                NaN
# 207915        NaN                 NaT                NaN
# 207916        NaN                 NaT                NaN
#
#                              email creation_source  \
# 0         AugustCClausen@yahoo.com    GUEST_INVITE
# 1           MatthewPoole@gustr.com      ORG_INVITE
# 2       MitchellBottrill@gustr.com      ORG_INVITE
# ...

# %%
len(df)
# Out:
# 219917

# %%
df.columns
# Out:
# Index(['object_id', 'creation_time', 'name', 'email', 'creation_source',
#        'last_session_creation_time', 'opted_in_to_mailing_list',
#        'enabled_for_marketing_drip', 'org_id', 'invited_by_user_id',
#        'time_stamp', 'user_id', 'visited'],
#       dtype='object')
